# %%
import numpy as np

shoaib_data = np.load("dataset/shoaib/data_20_120.npy")
shoaib_label = np.load("dataset/shoaib/label_20_120.npy")

shoaib_data.shape, shoaib_label.shape
# Out:
# ((10500, 120, 9), (10500, 120, 3))

# %%
print("Unique activity labels - ", np.unique(shoaib_label[:,0,0]))
# Out:
# Unique activity labels -  [0. 1. 2. 3. 4. 5. 6.]
